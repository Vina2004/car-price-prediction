# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cleaned_data.csv')
df
# Out:
#                   name   company  year     Price  kms_driven fuel_type  \
# 0          Santro Xing   Hyundai  2007   80000.0     45000.0    Petrol
# 1            Grand i10   Hyundai  2014  325000.0     28000.0    Petrol
# 2    EcoSport Titanium      Ford  2014  575000.0     36000.0    Diesel
# 3                 Figo      Ford  2012  175000.0     41000.0    Diesel
# 4                  Eon   Hyundai  2013  190000.0     25000.0    Petrol
# ..                 ...       ...   ...       ...         ...       ...
# 699        Suzuki Ritz    Maruti  2011  270000.0     50000.0    Petrol
# 700          Indica V2      Tata  2009  110000.0     30000.0    Diesel
# 701      Corolla Altis    Toyota  2009  300000.0    132000.0    Petrol
# 702            Zest XM      Tata  2018  260000.0     27000.0    Diesel
# 703          Quanto C8  Mahindra  2013  390000.0     40000.0    Diesel
#
#      kms_group
# 0      25k-50k
# 1      25k-50k
# 2      25k-50k
# 3      25k-50k
# 4        0-25k
# ..         ...
# 699    25k-50k
# 700    25k-50k
# 701  100k-150k
# 702    25k-50k
# 703    25k-50k
#
# [704 rows x 7 columns]

# %%
df = df.drop('kms_group', axis=1)

# %%
df
# Out:
#                   name   company  year     Price  kms_driven fuel_type
# 0          Santro Xing   Hyundai  2007   80000.0     45000.0    Petrol
# 1            Grand i10   Hyundai  2014  325000.0     28000.0    Petrol
# 2    EcoSport Titanium      Ford  2014  575000.0     36000.0    Diesel
# 3                 Figo      Ford  2012  175000.0     41000.0    Diesel
# 4                  Eon   Hyundai  2013  190000.0     25000.0    Petrol
# ..                 ...       ...   ...       ...         ...       ...
# 699        Suzuki Ritz    Maruti  2011  270000.0     50000.0    Petrol
# 700          Indica V2      Tata  2009  110000.0     30000.0    Diesel
# 701      Corolla Altis    Toyota  2009  300000.0    132000.0    Petrol
# 702            Zest XM      Tata  2018  260000.0     27000.0    Diesel
# 703          Quanto C8  Mahindra  2013  390000.0     40000.0    Diesel
#
# [704 rows x 6 columns]

# %%
#Lets divide dataset into X and y
X = df[['company', 'name', 'year', 'kms_driven', 'fuel_type']]
y = df[['Price']]

# %%
y
# Out:
#         Price
# 0     80000.0
# 1    325000.0
# 2    575000.0
# 3    175000.0
# 4    190000.0
# ..        ...
# 699  270000.0
# 700  110000.0
# 701  300000.0
# 702  260000.0
# 703  390000.0
#
# [704 rows x 1 columns]

# %%
X
# Out:
#       company               name  year  kms_driven fuel_type
# 0     Hyundai        Santro Xing  2007     45000.0    Petrol
# 1     Hyundai          Grand i10  2014     28000.0    Petrol
# 2        Ford  EcoSport Titanium  2014     36000.0    Diesel
# 3        Ford               Figo  2012     41000.0    Diesel
# 4     Hyundai                Eon  2013     25000.0    Petrol
# ..        ...                ...   ...         ...       ...
# 699    Maruti        Suzuki Ritz  2011     50000.0    Petrol
# 700      Tata          Indica V2  2009     30000.0    Diesel
# 701    Toyota      Corolla Altis  2009    132000.0    Petrol
# 702      Tata            Zest XM  2018     27000.0    Diesel
# 703  Mahindra          Quanto C8  2013     40000.0    Diesel
#
# [704 rows x 5 columns]

# %%
#Lets create pipeline which consists of columntransformer - whose job is to give numerical columns
#for string columns using OneHotEncoder and it returns other numerical columns as it is.
#After column transformer we create model object and put it in pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

ohe = OneHotEncoder()
ohe.fit(X[["company", "name", "fuel_type"]])
ct = make_column_transformer((OneHotEncoder(categories = ohe.categories_), 
                              ["company", "name", "fuel_type"]), remainder = 'passthrough')
model = LinearRegression()

pipe = make_pipeline(ct, model)

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Vol...
#        'XUV500 W10', 'XUV500 W6', 'XUV500 W8', 'Xcent Base', 'Xcent SX',
#        'Xylo D2', 'Xylo E4', 'Xylo E8', 'Yeti Ambition', 'Zest Quadrajet',
#        'Zest XE', 'Zest XM', 'i10', 'i10 Era', 'i10 Magna', 'i10 Sportz',
#        'i20', 'i20 Active', 'i20 Asta', 'i20 Magna', 'i20 Select',
#        'i20 Sportz'], dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
#Lets divide dataset into training and testing

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

scores = []

for i in range(0, 101):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05, random_state = i)
    #Lets train pipeline
    pipe.fit(X_train, y_train)
    #Lets find r2_score
    y_pred = pipe.predict(X_test)
    y_pred = pd.DataFrame(data = y_pred, columns = ['Prediction'])
    result = pd.concat([y_test.reset_index(drop = True), y_pred], axis = 1)
    score = r2_score(result['Price'], result['Prediction'])
    scores.append(score)

# %%
scores
# Out:
# [0.07743739585099207,
#  0.6379298926217596,
#  0.4919875682051307,
#  0.7143787550003242,
#  -0.23074902353390936,
#  0.6851330861692644,
#  -0.1066811413181088,
#  0.7715465644575381,
#  0.39771882029371175,
#  0.6471645499723689,
#  0.6822413378991283,
#  0.2485460472830091,
#  0.675712606602352,
#  -1.1182750531019674,
#  0.06978099125817938,
#  0.7609055133128464,
#  0.5171914767688328,
#  0.6462739068994905,
#  0.4991040767859438,
#  0.86007846217071,
#  0.3197869996482642,
#  0.06726511635223609,
#  0.5180600231751227,
#  0.5589550257222548,
#  0.7791753129945714,
#  0.5632467252457198,
#  0.8200623201810784,
#  0.13065038776478366,
#  0.7678489970347744,
#  0.3440882346250246,
#  -0.2817444289776718,
#  0.568349434085322,
#  0.44776503923922095,
#  0.7266335846470047,
#  0.6856400014405784,
#  0.7631513889840933,
#  0.7933385078591885,
#  0.5872285426308181,
#  0.21883122315659742,
#  0.5735707080591103,
#  0.06455836942805393,
#  0.21220055262100324,
#  0.7386497423979876,
#  -0.2672715235353931,
#  -0.9252303683456273,
#  -0.20684568209484722,
#  0.25872789959075915,
#  0.0694519159019843,
#  0.6189573507238562,
#  0.6857753765493617,
#  -0.1188945882937833,
#  0.058043916218195934,
#  0.7043407709233541,
#  0.5368793128940138,
#  0.5195341445275692,
#  0.5704925383496332,
#  -0.1180292561247478,
#  -2.2309423762400047,
#  0.4367048387914544,
#  0.6749072831400336,
#  0.35589569238787433,
#  0.06328102571421457,
#  -0.11975606818365869,
#  0.6896296469583058,
#  0.18523298499314234,
#  0.805808444571993,
#  0.5472701618277902,
#  0.7916968144230995,
#  0.5605199038389328,
#  0.5171607708073815,
#  0.7234625282632223,
#  0.5527999682428415,
#  0.6192738328430135,
#  -2.6180652721790545,
#  0.6926770297136393,
#  0.4335980986154204,
#  0.7736395504716108,
#  0.07150426427139911,
#  0.7818906803501248,
#  -1.0265676288439125,
#  0.7757371474764324,
#  0.5701516050777746,
#  0.6725640200415879,
#  0.31737631660654797,
#  0.33662163378608867,
#  0.5731157826840693,
#  0.49506475995502663,
#  0.6284439523513263,
#  0.750284204240315,
#  0.5492685001687936,
#  0.7885886842450962,
#  -1.0857242120779649,
#  0.052694848641982706,
#  0.6851049597882235,
#  0.5017826949350999,
#  -1.1964894824277406,
#  0.6807306560953376,
#  0.7304816168938992,
#  0.4795593560798882,
#  0.7452693158646893,
#  -0.6441089547050176]

# %%
#Find index of max score
index = np.argmax(scores)
index
# Out:
# np.int64(19)

# %%
#Lets retrain with best index
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05, random_state = index)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Vol...
#        'XUV500 W10', 'XUV500 W6', 'XUV500 W8', 'Xcent Base', 'Xcent SX',
#        'Xylo D2', 'Xylo E4', 'Xylo E8', 'Yeti Ambition', 'Zest Quadrajet',
#        'Zest XE', 'Zest XM', 'i10', 'i10 Era', 'i10 Magna', 'i10 Sportz',
#        'i20', 'i20 Active', 'i20 Asta', 'i20 Magna', 'i20 Select',
#        'i20 Sportz'], dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
data = [['Ford', 'EcoSport', 2015, 80000, 'Petrol']]
columns = ['company', 'name', 'year', 'kms_driven', 'fuel_type']
myinput = pd.DataFrame(data = data, columns = columns)
price = pipe.predict(myinput)
print("You can purchase this car for:", round(price[0,0]))
# Out:
# You can purchase this car for: 547696

# %%
#To get input from user and provide output we must develop web application
#We can use Python - Flask, FastAPI, Django or Streamlit
#We cannot train model all the time, so lets export out trained model(pipe) using pickle library
import pickle as pkl
pkl.dump(pipe, open('car-price-predictor.pkl', 'wb'))
